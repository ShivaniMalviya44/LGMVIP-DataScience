# %% [markdown]
# ## LetsGrowMore
# ## TASK 4 :  Image to Pencil Sketch with Python
# ## By : Shivani Malviya¶

# %% [markdown]
# ### 1. Importing Required libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
print("Necessary packages included successfully!")
# Out:
# Necessary packages included successfully!

# %% [markdown]
# ### 2.  Loading the Image

# %%
image=cv2.imread("cat.jfif")
image = cv2.resize(image,(500,300))
image
# Out:
# array([[[ 86, 101, 127],
#         [ 85, 101, 126],
#         [ 85, 100, 126],
#         ...,
#         [ 17,  69,  59],
#         [ 17,  69,  59],
#         [ 17,  69,  59]],
#
#        [[ 87, 102, 128],
#         [ 87, 101, 128],
#         [ 86, 101, 127],
#         ...,
#         [ 17,  69,  59],
#         [ 18,  69,  59],
#         [ 18,  69,  59]],
#
#        [[ 88, 103, 129],
#         [ 88, 103, 129],
#         [ 88, 103, 129],
#         ...,
#         [ 18,  70,  60],
#         [ 19,  70,  60],
#         [ 20,  70,  60]],
#
#        ...,
#
#        [[196, 223, 237],
#         [197, 224, 238],
#         [197, 224, 238],
#         ...,
#         [194, 218, 242],
#         [194, 218, 242],
#         [194, 218, 242]],
#
#        [[206, 234, 246],
#         [207, 234, 246],
#         [208, 235, 247],
#         ...,
#         [182, 206, 230],
#         [182, 206, 230],
#         [182, 206, 230]],
#
#        [[212, 240, 251],
#         [212, 241, 252],
#         [214, 242, 253],
#         ...,
#         [174, 198, 222],
#         [174, 198, 222],
#         [174, 198, 222]]], dtype=uint8)

# %%
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# ### 3. Converting into Gray Scale

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[107, 107, 106, ...,  60,  60,  60],
#        [108, 107, 107, ...,  60,  60,  60],
#        [109, 109, 109, ...,  61,  61,  61],
#        ...,
#        [224, 225, 225, ..., 222, 222, 222],
#        [234, 235, 236, ..., 210, 210, 210],
#        [240, 241, 242, ..., 202, 202, 202]], dtype=uint8)

# %%
plt.imshow(gray_image)

# %% [markdown]
# ### 4. Inverting the image

# %%
inverted_image = cv2.bitwise_not(gray_image)
inverted_image
# Out:
# array([[148, 148, 149, ..., 195, 195, 195],
#        [147, 148, 148, ..., 195, 195, 195],
#        [146, 146, 146, ..., 194, 194, 194],
#        ...,
#        [ 31,  30,  30, ...,  33,  33,  33],
#        [ 21,  20,  19, ...,  45,  45,  45],
#        [ 15,  14,  13, ...,  53,  53,  53]], dtype=uint8)

# %%
plt.imshow(inverted_image)

# %% [markdown]
# ### 5. Smoothing the image

# %%
img_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
img_smoothing
# Out:
# array([[145, 145, 146, ..., 193, 193, 193],
#        [145, 145, 145, ..., 192, 193, 193],
#        [145, 145, 145, ..., 192, 193, 193],
#        ...,
#        [ 68,  68,  68, ...,  38,  38,  38],
#        [ 61,  61,  61, ...,  38,  38,  38],
#        [ 59,  59,  59, ...,  38,  38,  38]], dtype=uint8)

# %%
plt.imshow(img_smoothing)

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256.0)

# %% [markdown]
# ### 6.  Inverting the Image to get the Pencil Sketch

# %%
pencil_sketch = dodgeV2(gray_image, img_smoothing)
plt.imshow(pencil_sketch)

# %% [markdown]
# ### 7. Comparing the Original Image with Pencil Sketch

# %%
display(Image.fromarray(img_rgb))
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x1DBE635C970>
# <PIL.Image.Image image mode=L size=500x300 at 0x1DBE635C4F0>

# %%
cv2.imshow("Sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# #### Conclusion: RBG format image converted into grayscale image

# %% [markdown]
# ## Thank You!
