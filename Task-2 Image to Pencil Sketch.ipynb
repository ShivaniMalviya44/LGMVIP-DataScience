# %% [markdown]
# ## LetsGrowMore
# ## TASK 2 :  Image to Pencil Sketch with Python
# ## By : Shivani Malviya¶

# %% [markdown]
# ### 1. Importing Required libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
print("Necessary packages included successfully!")
# Out:
# Necessary packages included successfully!

# %% [markdown]
# ### 2.  Loading the Image

# %%
image=cv2.imread("cat.jfif")
image = cv2.resize(image,(500,300))
image
# Out:
# array([[[ 86, 101, 127],
#         [ 85, 101, 126],
#         [ 85, 100, 126],
#         ...,
#         [ 17,  69,  59],
#         [ 17,  69,  59],
#         [ 17,  69,  59]],
#
#        [[ 87, 102, 128],
#         [ 87, 101, 128],
#         [ 86, 101, 127],
#         ...,
#         [ 17,  69,  59],
#         [ 18,  69,  59],
#         [ 18,  69,  59]],
#
#        [[ 88, 103, 129],
#         [ 88, 103, 129],
#         [ 88, 103, 129],
#         ...,
#         [ 18,  70,  60],
#         [ 19,  70,  60],
#         [ 20,  70,  60]],
#
#        ...,
#
#        [[196, 223, 237],
#         [197, 224, 238],
#         [197, 224, 238],
#         ...,
#         [194, 218, 242],
#         [194, 218, 242],
#         [194, 218, 242]],
#
#        [[206, 234, 246],
#         [207, 234, 246],
#         [208, 235, 247],
#         ...,
#         [182, 206, 230],
#         [182, 206, 230],
#         [182, 206, 230]],
#
#        [[212, 240, 251],
#         [212, 241, 252],
#         [214, 242, 253],
#         ...,
#         [174, 198, 222],
#         [174, 198, 222],
#         [174, 198, 222]]], dtype=uint8)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# ### 3. Converting into Gray Scale

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[107, 106, 106, ...,  60,  60,  60],
#        [109, 109, 108, ...,  61,  61,  61],
#        [112, 112, 111, ...,  61,  61,  61],
#        ...,
#        [164, 165, 167, ..., 230, 230, 230],
#        [226, 227, 228, ..., 222, 222, 222],
#        [240, 242, 243, ..., 202, 202, 202]], dtype=uint8)

# %%
plt.imshow(gray_image)

# %% [markdown]
# ### 4. Inverting the image

# %%
inverted_image = cv2.bitwise_not(gray_image)
inverted_image
# Out:
# array([[148, 149, 149, ..., 195, 195, 195],
#        [146, 146, 147, ..., 194, 194, 194],
#        [143, 143, 144, ..., 194, 194, 194],
#        ...,
#        [ 91,  90,  88, ...,  25,  25,  25],
#        [ 29,  28,  27, ...,  33,  33,  33],
#        [ 15,  13,  12, ...,  53,  53,  53]], dtype=uint8)

# %%
plt.imshow(inverted_image)

# %% [markdown]
# ### 5. Smoothing the image

# %%
img_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
img_smoothing
# Out:
# array([[145, 145, 146, ..., 188, 189, 189],
#        [145, 145, 146, ..., 187, 188, 189],
#        [145, 146, 146, ..., 186, 187, 188],
#        ...,
#        [ 99,  99,  99, ...,  48,  47,  46],
#        [ 93,  93,  93, ...,  46,  45,  45],
#        [ 91,  91,  91, ...,  46,  45,  44]], dtype=uint8)

# %%
plt.imshow(img_smoothing)

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256.0)

# %% [markdown]
# ### 6.  Inverting the Image to get the Pencil Sketch

# %%
pencil_sketch = dodgeV2(gray_image, img_smoothing)
plt.imshow(pencil_sketch)

# %% [markdown]
# ### 7. Comparing the Original Image with Pencil Sketch

# %%
display(Image.fromarray(img_rgb))
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x2891AFF6A30>
# <PIL.Image.Image image mode=L size=275x183 at 0x28918E4DCA0>

# %%
cv2.imshow("Sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# #### Conclusion: RBG format image converted into grayscale image

# %% [markdown]
# ## Thank You!
